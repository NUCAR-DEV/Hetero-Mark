# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/home/yifan/dev/src/gitlab.com/NUCAR-DEV/Hetero-Mark/build/src/fdeb/hc/out_gpu.data', header=None);data
# Out:
#            0         1         2         3         4         5         6    \
# 0     8.299410  0.555270  8.284140  0.618329  8.269550  0.681059  8.256040
# 1     5.354160  5.986140  5.285270  5.902370  5.216900  5.819170  5.148180
# 2     3.402200  9.625660  3.408000  9.557610  3.413690  9.490300  3.419040
# 3     2.870810  0.368039  2.933790  0.402845  2.996520  0.436944  3.058840
# 4     8.859390  1.933430  8.841020  2.031980  8.823220  2.130030  8.806250
# 5     0.889772  1.547850  0.927001  1.601740  0.963641  1.655160  0.999456
# 6     8.159130  1.006080  8.033200  1.099940  7.907800  1.193280  7.783250
# 7     9.638390  6.031860  9.522910  6.055870  9.408160  6.080070  9.294500
# 8     2.492170  2.213080  2.495740  2.274420  2.498860  2.335150  2.501240
# 9     3.534620  5.910280  3.594100  5.821400  3.653560  5.733600  3.711620
# 10    3.127490  8.085700  3.110330  7.988800  3.092860  7.892580  3.074960
# ...

# %%
data_in = pd.read_csv('/home/yifan/dev/src/gitlab.com/NUCAR-DEV/Hetero-Mark/data/fdeb/1000x3000.csv', header=None);data_in
# data_in = pd.read_csv('/home/yifan/dev/src/gitlab.com/NUCAR-DEV/Hetero-Mark/build/src/fdeb/hc/out_cpu.data', header=None);data_in
# Out:
#              0         1         2         3   4
# 0     8.299407  0.555270  8.079356  3.837007 NaN
# 1     5.354163  5.986143  0.663591  0.846431 NaN
# 2     3.402203  9.625665  3.454208  6.286048 NaN
# 3     2.870813  0.368039  6.588618  1.574018 NaN
# 4     8.859385  1.933429  8.677030  7.950123 NaN
# 5     0.889772  1.547852  2.410400  4.369563 NaN
# 6     8.159131  1.006075  0.351090  6.117129 NaN
# 7     9.638385  6.031856  3.215702  7.980713 NaN
# 8     2.492172  2.213085  1.876546  5.488773 NaN
# 9     3.534624  5.910281  6.690076  0.064235 NaN
# 10    3.127486  8.085701  1.245601  2.465336 NaN
# 11    0.441686  2.402905  5.067951  4.555248 NaN
# 12    8.972010  4.352703  2.895309  3.947920 NaN
# 13    8.263261  4.758560  5.035629  9.334479 NaN
# 14    5.507772  7.408788  5.173834  9.000525 NaN
# 15    3.336129  9.551472  6.862965  7.419539 NaN
# 16    8.193318  3.083607  8.454246  3.423125 NaN
# 17    2.835213  6.532936  3.683315  9.884591 NaN
# ...

# %%
lines = []
def iterate_row(data):
    line = []
    for i in range(0, len(data)/2):
        point = (data[i*2], data[i*2 + 1])
        line.append(point)
    lines.append(line)
data.apply(iterate_row, axis=1);

# %%
lines_in = []
def iterate_row(data):
    line = []
    for i in range(0, len(data)/2):
        point = (data[i*2], data[i*2 + 1])
        line.append(point)
    lines_in.append(line)
data_in.apply(iterate_row, axis=1);

# %%
line_collections = mpl.collections.LineCollection(lines, color='r', lw=0.05)
line_in_collections = mpl.collections.LineCollection(lines_in, color='b', lw=0.05)
fig, ax = plt.subplots(figsize=(10, 10))

ax.add_collection(line_in_collections)
ax.add_collection(line_collections)

plt.xlim([0, 10])
plt.ylim([0, 10])
plt.savefig('out_bundle.eps')
